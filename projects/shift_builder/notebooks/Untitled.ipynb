# %%
conda install -c anaconda matplotlib
# Out:
# Retrieving notices: done
# Channels:
#  - anaconda
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/hiraokatatsuru/miniconda3/envs/shift_builder
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.3.1            |  py312h48ca7d4_0         290 KB  anaconda
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB  anaconda
#     fonttools-4.55.3           |  py312h80987f9_0         3.0 MB  anaconda
#     freetype-2.13.3            |       h47d26ad_0         880 KB  anaconda
#     jpeg-9e                    |       h80987f9_3         268 KB  anaconda
#     kiwisolver-1.4.8           |  py312h313beb8_0          69 KB  anaconda
#     lcms2-2.16                 |       he26ebf3_1         241 KB  anaconda
#     lerc-4.0.0                 |       h313beb8_0         217 KB  anaconda
#     libdeflate-1.22            |       h80987f9_0          59 KB  anaconda
#     libpng-1.6.39              |       h80987f9_0         313 KB  anaconda
#     libtiff-4.7.0              |       h91aec0a_0         398 KB  anaconda
#     libwebp-base-1.3.2         |       h80987f9_1         334 KB  anaconda
#     matplotlib-3.10.0          |  py312hca03da5_0           8 KB  anaconda
#     matplotlib-base-3.10.0     |  py312h7ef442a_0         9.1 MB  anaconda
#     openjpeg-2.5.2             |       hba36e21_1         439 KB  anaconda
#     pillow-11.1.0              |  py312h41ba818_1         906 KB  anaconda
#     unicodedata2-15.1.0        |  py312h80987f9_1         506 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        16.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   contourpy          anaconda/osx-arm64::contourpy-1.3.1-py312h48ca7d4_0
#   cycler             anaconda/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          anaconda/osx-arm64::fonttools-4.55.3-py312h80987f9_0
#   freetype           anaconda/osx-arm64::freetype-2.13.3-h47d26ad_0
#   jpeg               anaconda/osx-arm64::jpeg-9e-h80987f9_3
#   kiwisolver         anaconda/osx-arm64::kiwisolver-1.4.8-py312h313beb8_0
#   lcms2              anaconda/osx-arm64::lcms2-2.16-he26ebf3_1
#   lerc               anaconda/osx-arm64::lerc-4.0.0-h313beb8_0
#   libdeflate         anaconda/osx-arm64::libdeflate-1.22-h80987f9_0
#   libpng             anaconda/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            anaconda/osx-arm64::libtiff-4.7.0-h91aec0a_0
#   libwebp-base       anaconda/osx-arm64::libwebp-base-1.3.2-h80987f9_1
#   matplotlib         anaconda/osx-arm64::matplotlib-3.10.0-py312hca03da5_0
#   matplotlib-base    anaconda/osx-arm64::matplotlib-base-3.10.0-py312h7ef442a_0
#   openjpeg           anaconda/osx-arm64::openjpeg-2.5.2-hba36e21_1
#   pillow             anaconda/osx-arm64::pillow-11.1.0-py312h41ba818_1
#   unicodedata2       anaconda/osx-arm64::unicodedata2-15.1.0-py312h80987f9_1
#
#
#
# Downloading and Extracting Packages:
# matplotlib-base-3.10 | 9.1 MB    |                                       |   0%
# fonttools-4.55.3     | 3.0 MB    |                                       |   0%
#
# pillow-11.1.0        | 906 KB    |                                       |   0%
#
#
# freetype-2.13.3      | 880 KB    |                                       |   0%
#
#
#
# unicodedata2-15.1.0  | 506 KB    |                                       |   0%
#
#
#
#
# openjpeg-2.5.2       | 439 KB    |                                       |   0%
#
#
#
#
#
# libtiff-4.7.0        | 398 KB    |                                       |   0%
#
#
#
#
#
#
# libwebp-base-1.3.2   | 334 KB    |                                       |   0%
#
#
#
#
#
#
#
# libpng-1.6.39        | 313 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 290 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 268 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 241 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 217 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.8     | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 59 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 8 KB      |                                       |   0%
#
# pillow-11.1.0        | 906 KB    | 6                                     |   2%
#
# pillow-11.1.0        | 906 KB    | ####################9                 |  57%
#
#
# freetype-2.13.3      | 880 KB    | 6                                     |   2%
#
#
# freetype-2.13.3      | 880 KB    | #######3                              |  20%
#
# pillow-11.1.0        | 906 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 906 KB    | ##################################### | 100%
#
#
# freetype-2.13.3      | 880 KB    | ##############################9       |  84%
#
# pillow-11.1.0        | 906 KB    | ##################################### | 100%
#
#
# freetype-2.13.3      | 880 KB    | ##################################### | 100%
#
#
#
#
# openjpeg-2.5.2       | 439 KB    | #3                                    |   4%
#
#
# freetype-2.13.3      | 880 KB    | ##################################### | 100%
#
#
#
#
#
# libtiff-4.7.0        | 398 KB    | #4                                    |   4%
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    |                                       |   0%
#
#
#
#
#
# libtiff-4.7.0        | 398 KB    | #############################7        |  80%
#
#
#
#
#
# libtiff-4.7.0        | 398 KB    | ##################################### | 100%
#
#
#
#
# openjpeg-2.5.2       | 439 KB    | ##################################### | 100%
#
#
#
#
#
# libtiff-4.7.0        | 398 KB    | ##################################### | 100%
#
#
#
#
# openjpeg-2.5.2       | 439 KB    | ##################################### | 100%
# matplotlib-base-3.10 | 9.1 MB    | 5                                     |   1%
#
#
#
# unicodedata2-15.1.0  | 506 KB    | #1                                    |   3%
#
#
#
#
#
#
# libwebp-base-1.3.2   | 334 KB    | #7                                    |   5%
# matplotlib-base-3.10 | 9.1 MB    | 8                                     |   2%
#
#
#
#
#
#
# libwebp-base-1.3.2   | 334 KB    | ##################################### | 100%
#
#
#
# unicodedata2-15.1.0  | 506 KB    | ####6                                 |  13%
#
#
#
#
#
#
# libwebp-base-1.3.2   | 334 KB    | ##################################### | 100%
#
#
#
#
#
#
# libwebp-base-1.3.2   | 334 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | #3                                    |   4%
# fonttools-4.55.3     | 3.0 MB    | ####4                                 |  12%
#
#
#
# unicodedata2-15.1.0  | 506 KB    | #########3                            |  25%
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | #9                                    |   5%
# fonttools-4.55.3     | 3.0 MB    | ######1                               |  17%
#
#
#
#
#
#
#
# libpng-1.6.39        | 313 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ##9                                   |   8%
#
#
#
# unicodedata2-15.1.0  | 506 KB    | ###############2                      |  41%
# fonttools-4.55.3     | 3.0 MB    | #########2                            |  25%
#
#
#
# unicodedata2-15.1.0  | 506 KB    | ##############################4       |  82%
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 290 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 268 KB    | ##2                                   |   6%
# fonttools-4.55.3     | 3.0 MB    | ###########                           |  30%
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 290 KB    | ############2                         |  33%
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ###5                                  |  10%
# fonttools-4.55.3     | 3.0 MB    | ############5                         |  34%
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 290 KB    | ##################3                   |  50%
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 290 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 290 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 268 KB    | #################################1    |  90%
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 268 KB    | ##################################### | 100%
# matplotlib-base-3.10 | 9.1 MB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 268 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ######9                               |  19%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 241 KB    | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 217 KB    | ##7                                   |   7%
# matplotlib-base-3.10 | 9.1 MB    | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 241 KB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 241 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 241 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | #########7                            |  26%
# fonttools-4.55.3     | 3.0 MB    | ############################5         |  77%
#
#
#
# unicodedata2-15.1.0  | 506 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 217 KB    | ###################1                  |  52%
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 217 KB    | ################################7     |  89%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 217 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 217 KB    | ##################################### | 100%
# fonttools-4.55.3     | 3.0 MB    | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 59 KB     | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 59 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 59 KB     | ##################################### | 100%
# matplotlib-base-3.10 | 9.1 MB    | #############3                        |  36%
# matplotlib-base-3.10 | 9.1 MB    | ##############3                       |  39%
# matplotlib-base-3.10 | 9.1 MB    | ###############7                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ##################3                   |  49%
# matplotlib-base-3.10 | 9.1 MB    | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.8     | 69 KB     | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 9.1 MB    | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda install -y scikit-learn
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/hiraokatatsuru/miniconda3
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          10 KB
#     certifi-2025.4.26          |  py312hca03da5_0         158 KB
#     conda-25.5.0               |  py312hca03da5_0         1.2 MB
#     joblib-1.4.2               |  py312hca03da5_0         516 KB
#     libgfortran-5.0.0          |11_3_0_hca03da5_28         142 KB
#     libgfortran5-11.3.0        |      h009349e_28         1.0 MB
#     libopenblas-0.3.29         |       hea593b9_0        10.1 MB
#     llvm-openmp-14.0.6         |       hc6e5704_0         253 KB
#     numpy-2.0.1                |  py312h7f4fdc5_1          12 KB
#     numpy-base-2.0.1           |  py312he047099_1         6.6 MB
#     scikit-learn-1.6.1         |  py312h313beb8_0         9.8 MB
#     scipy-1.15.3               |  py312hb81b3df_0        22.0 MB
#     threadpoolctl-3.5.0        |  py312h989b03a_0          49 KB
#     ------------------------------------------------------------
#                                            Total:        51.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   joblib             pkgs/main/osx-arm64::joblib-1.4.2-py312hca03da5_0
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.29-hea593b9_0
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-14.0.6-hc6e5704_0
#   numpy              pkgs/main/osx-arm64::numpy-2.0.1-py312h7f4fdc5_1
#   numpy-base         pkgs/main/osx-arm64::numpy-base-2.0.1-py312he047099_1
#   scikit-learn       pkgs/main/osx-arm64::scikit-learn-1.6.1-py312h313beb8_0
#   scipy              pkgs/main/osx-arm64::scipy-1.15.3-py312hb81b3df_0
#   threadpoolctl      pkgs/main/osx-arm64::threadpoolctl-3.5.0-py312h989b03a_0
#
# The following packages will be UPDATED:
#
#   certifi                         2025.1.31-py312hca03da5_0 --> 2025.4.26-py312hca03da5_0
#   conda                              25.3.1-py312hca03da5_0 --> 25.5.0-py312hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# scipy-1.15.3         | 22.0 MB   |                                       |   0%
# libopenblas-0.3.29   | 10.1 MB   |                                       |   0%
#
# scikit-learn-1.6.1   | 9.8 MB    |                                       |   0%
#
#
# numpy-base-2.0.1     | 6.6 MB    |                                       |   0%
#
#
#
# conda-25.5.0         | 1.2 MB    |                                       |   0%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    |                                       |   0%
#
#
#
#
#
# joblib-1.4.2         | 516 KB    |                                       |   0%
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 253 KB    |                                       |   0%
#
#
#
#
#
#
#
# certifi-2025.4.26    | 158 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 49 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# numpy-2.0.1          | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     |                                       |   0%
#
# scipy-1.15.3         | 22.0 MB   |                                       |   0%
# libopenblas-0.3.29   | 10.1 MB   |                                       |   0%
#
#
#
# conda-25.5.0         | 1.2 MB    | 4                                     |   1%
#
#
# numpy-base-2.0.1     | 6.6 MB    | 7                                     |   2%
#
# scipy-1.15.3         | 22.0 MB   | 2                                     |   1%
# libopenblas-0.3.29   | 10.1 MB   | 4                                     |   1%
#
#
#
# conda-25.5.0         | 1.2 MB    | #4                                    |   4%
#
#
# scipy-1.15.3         | 22.0 MB   | 3                                     |   1%
#
#
#
# conda-25.5.0         | 1.2 MB    | ###4                                  |   9%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #7                                    |   5%
#
# scikit-learn-1.6.1   | 9.8 MB    | 8                                     |   2%
# scipy-1.15.3         | 22.0 MB   | 5                                     |   2%
#
#
#
# conda-25.5.0         | 1.2 MB    | ####4                                 |  12%
#
#
# scipy-1.15.3         | 22.0 MB   | 6                                     |   2%
# libopenblas-0.3.29   | 10.1 MB   | #4                                    |   4%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ###5                                  |  10%
#
# scikit-learn-1.6.1   | 9.8 MB    | #1                                    |   3%
#
#
#
# conda-25.5.0         | 1.2 MB    | #######9                              |  21%
# scipy-1.15.3         | 22.0 MB   | 8                                     |   2%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ####9                                 |  13%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##8                                   |   8%
# scipy-1.15.3         | 22.0 MB   | #3                                    |   4%
#
#
#
# conda-25.5.0         | 1.2 MB    | ##############3                       |  39%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #####9                                |  16%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###6                                  |  10%
#
#
#
# conda-25.5.0         | 1.2 MB    | #################8                    |  48%
# scipy-1.15.3         | 22.0 MB   | #6                                    |   4%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ######7                               |  18%
#
# scikit-learn-1.6.1   | 9.8 MB    | ####3                                 |  12%
#
#
#
# conda-25.5.0         | 1.2 MB    | #####################2                |  58%
# scipy-1.15.3         | 22.0 MB   | #8                                    |   5%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #######6                              |  21%
#
# scikit-learn-1.6.1   | 9.8 MB    | ####9                                 |  14%
# libopenblas-0.3.29   | 10.1 MB   | ####3                                 |  12%
#
#
#
# scipy-1.15.3         | 22.0 MB   | ##1                                   |   6%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ########5                             |  23%
# libopenblas-0.3.29   | 10.1 MB   | ####7                                 |  13%
#
# scikit-learn-1.6.1   | 9.8 MB    | #####5                                |  15%
#
#
#
# scipy-1.15.3         | 22.0 MB   | ##3                                   |   6%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #########3                            |  25%
#
#
#
# conda-25.5.0         | 1.2 MB    | ###############################1      |  84%
# libopenblas-0.3.29   | 10.1 MB   | #####3                                |  14%
#
# scipy-1.15.3         | 22.0 MB   | ##7                                   |   7%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ##########1                           |  27%
#
#
#
# conda-25.5.0         | 1.2 MB    | ##################################6   |  94%
#
# scikit-learn-1.6.1   | 9.8 MB    | ######7                               |  18%
# libopenblas-0.3.29   | 10.1 MB   | #####8                                |  16%
#
#
#
# scipy-1.15.3         | 22.0 MB   | ##9                                   |   8%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ###########                           |  30%
#
# scikit-learn-1.6.1   | 9.8 MB    | #######2                              |  20%
# libopenblas-0.3.29   | 10.1 MB   | ######3                               |  17%
#
#
#
# conda-25.5.0         | 1.2 MB    | ##################################### | 100%
#
#
# scipy-1.15.3         | 22.0 MB   | ###1                                  |   9%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | 5                                     |   2%
#
# scikit-learn-1.6.1   | 9.8 MB    | #######8                              |  21%
# libopenblas-0.3.29   | 10.1 MB   | ######7                               |  18%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ############8                         |  35%
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ###4                                  |   9%
#
# scikit-learn-1.6.1   | 9.8 MB    | ########3                             |  23%
# libopenblas-0.3.29   | 10.1 MB   | #######2                              |  20%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | #######8                              |  21%
#
#
# scipy-1.15.3         | 22.0 MB   | ###6                                  |  10%
#
# scikit-learn-1.6.1   | 9.8 MB    | ########8                             |  24%
# libopenblas-0.3.29   | 10.1 MB   | #######7                              |  21%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | ###########2                          |  30%
#
#
# scipy-1.15.3         | 22.0 MB   | ###8                                  |  11%
#
# scikit-learn-1.6.1   | 9.8 MB    | #########4                            |  25%
# libopenblas-0.3.29   | 10.1 MB   | ########2                             |  22%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | ##############6                       |  40%
#
#
# scipy-1.15.3         | 22.0 MB   | ####1                                 |  11%
#
# scikit-learn-1.6.1   | 9.8 MB    | #########9                            |  27%
# libopenblas-0.3.29   | 10.1 MB   | ########7                             |  24%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | ##################5                   |  50%
#
#
# scipy-1.15.3         | 22.0 MB   | ####3                                 |  12%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##########4                           |  28%
# libopenblas-0.3.29   | 10.1 MB   | #########2                            |  25%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | #####################9                |  59%
#
#
# scipy-1.15.3         | 22.0 MB   | ####6                                 |  12%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##########9                           |  30%
# libopenblas-0.3.29   | 10.1 MB   | #########7                            |  26%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #################7                    |  48%
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ####8                                 |  13%
# libopenblas-0.3.29   | 10.1 MB   | ##########2                           |  28%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###########4                          |  31%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ##################5                   |  50%
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | #####                                 |  14%
# libopenblas-0.3.29   | 10.1 MB   | ##########7                           |  29%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###########8                          |  32%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ###################3                  |  52%
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | #####3                                |  14%
# libopenblas-0.3.29   | 10.1 MB   | ###########3                          |  31%
#
# scikit-learn-1.6.1   | 9.8 MB    | ############3                         |  33%
#
#
# scipy-1.15.3         | 22.0 MB   | #####5                                |  15%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | ####################################  |  97%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | ##################################### | 100%
# libopenblas-0.3.29   | 10.1 MB   | ###########8                          |  32%
#
# scikit-learn-1.6.1   | 9.8 MB    | ############8                         |  35%
#
#
#
#
# libgfortran5-11.3.0  | 1.0 MB    | ##################################### | 100%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ####################9                 |  56%
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | #####8                                |  16%
# libopenblas-0.3.29   | 10.1 MB   | ############3                         |  33%
#
# scikit-learn-1.6.1   | 9.8 MB    | #############2                        |  36%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #####################6                |  59%
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ######                                |  16%
# libopenblas-0.3.29   | 10.1 MB   | #############                         |  35%
#
# scikit-learn-1.6.1   | 9.8 MB    | #############7                        |  37%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ######################4               |  61%
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ######2                               |  17%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##############2                       |  38%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #######################2              |  63%
#
#
#
#
#
# joblib-1.4.2         | 516 KB    | ##################3                   |  50%
# scipy-1.15.3         | 22.0 MB   | ######5                               |  18%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##############6                       |  40%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #######################9              |  65%
# libopenblas-0.3.29   | 10.1 MB   | ##############                        |  38%
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ######7                               |  18%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###############                       |  41%
# libopenblas-0.3.29   | 10.1 MB   | ##############4                       |  39%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ########################6             |  67%
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ######9                               |  19%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###############4                      |  42%
# libopenblas-0.3.29   | 10.1 MB   | ##############9                       |  40%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #########################4            |  69%
#
#
#
#
#
# joblib-1.4.2         | 516 KB    | ###################################5  |  96%
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | #######2                              |  19%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###############9                      |  43%
#
#
#
#
#
# joblib-1.4.2         | 516 KB    | ##################################### | 100%
# libopenblas-0.3.29   | 10.1 MB   | ###############3                      |  42%
#
#
# scipy-1.15.3         | 22.0 MB   | #######4                              |  20%
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 253 KB    | ##3                                   |   6%
#
# scikit-learn-1.6.1   | 9.8 MB    | ################4                     |  45%
# libopenblas-0.3.29   | 10.1 MB   | ###############9                      |  43%
#
#
# scipy-1.15.3         | 22.0 MB   | #######7                              |  21%
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 253 KB    | ################3                     |  44%
#
# scikit-learn-1.6.1   | 9.8 MB    | ################9                     |  46%
# libopenblas-0.3.29   | 10.1 MB   | ################4                     |  45%
#
#
# scipy-1.15.3         | 22.0 MB   | #######9                              |  22%
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 253 KB    | ##############################3       |  82%
#
# scikit-learn-1.6.1   | 9.8 MB    | #################4                    |  47%
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 253 KB    | ##################################### | 100%
# libopenblas-0.3.29   | 10.1 MB   | ################9                     |  46%
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 253 KB    | ##################################### | 100%
#
#
# scipy-1.15.3         | 22.0 MB   | ########2                             |  22%
#
#
#
#
#
#
#
# certifi-2025.4.26    | 158 KB    | ###7                                  |  10%
#
# scikit-learn-1.6.1   | 9.8 MB    | #################9                    |  48%
# libopenblas-0.3.29   | 10.1 MB   | #################4                    |  47%
#
#
# scipy-1.15.3         | 22.0 MB   | ########4                             |  23%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
# certifi-2025.4.26    | 158 KB    | ##########################2           |  71%
# libopenblas-0.3.29   | 10.1 MB   | #################9                    |  49%
#
#
# numpy-base-2.0.1     | 6.6 MB    | #############################8        |  81%
#
#
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | ########7                             |  24%
#
#
#
#
#
#
#
# certifi-2025.4.26    | 158 KB    | ##################################### | 100%
#
# scikit-learn-1.6.1   | 9.8 MB    | ##################8                   |  51%
# libopenblas-0.3.29   | 10.1 MB   | ##################4                   |  50%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ####1                                 |  11%
#
#
# scipy-1.15.3         | 22.0 MB   | ########9                             |  24%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###################3                  |  52%
# libopenblas-0.3.29   | 10.1 MB   | ##################8                   |  51%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ###############################2      |  84%
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | #########2                            |  25%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ##################################### | 100%
#
# scikit-learn-1.6.1   | 9.8 MB    | ###################8                  |  54%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ##################################### | 100%
# libopenblas-0.3.29   | 10.1 MB   | ###################3                  |  52%
#
#
# scipy-1.15.3         | 22.0 MB   | #########4                            |  26%
#
# scikit-learn-1.6.1   | 9.8 MB    | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 49 KB     | ############                          |  33%
# libopenblas-0.3.29   | 10.1 MB   | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 49 KB     | ##################################### | 100%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ################################6     |  88%
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 22.0 MB   | #########7                            |  26%
#
# scikit-learn-1.6.1   | 9.8 MB    | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
#
# numpy-2.0.1          | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# numpy-2.0.1          | 12 KB     | ##################################### | 100%
# libopenblas-0.3.29   | 10.1 MB   | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
#
# numpy-2.0.1          | 12 KB     | ##################################### | 100%
#
#
# scipy-1.15.3         | 22.0 MB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
#
# scikit-learn-1.6.1   | 9.8 MB    | #####################4                |  58%
# libopenblas-0.3.29   | 10.1 MB   | ####################8                 |  56%
#
#
# scipy-1.15.3         | 22.0 MB   | ##########3                           |  28%
# libopenblas-0.3.29   | 10.1 MB   | #####################4                |  58%
#
# scikit-learn-1.6.1   | 9.8 MB    | #####################9                |  59%
#
#
# scipy-1.15.3         | 22.0 MB   | ##########6                           |  29%
# libopenblas-0.3.29   | 10.1 MB   | ######################                |  60%
#
# scikit-learn-1.6.1   | 9.8 MB    | ######################5               |  61%
#
#
# scipy-1.15.3         | 22.0 MB   | ##########9                           |  30%
# libopenblas-0.3.29   | 10.1 MB   | ######################5               |  61%
#
# scikit-learn-1.6.1   | 9.8 MB    | #######################1              |  62%
#
#
# scipy-1.15.3         | 22.0 MB   | ###########2                          |  30%
# libopenblas-0.3.29   | 10.1 MB   | #######################1              |  63%
#
#
# numpy-base-2.0.1     | 6.6 MB    | ##################################### | 100%
#
# scipy-1.15.3         | 22.0 MB   | ###########5                          |  31%
# libopenblas-0.3.29   | 10.1 MB   | #######################8              |  64%
#
# scipy-1.15.3         | 22.0 MB   | ###########9                          |  32%
# libopenblas-0.3.29   | 10.1 MB   | ########################6             |  67%
#
# scikit-learn-1.6.1   | 9.8 MB    | #########################             |  68%
#
#
# scipy-1.15.3         | 22.0 MB   | ############3                         |  33%
# libopenblas-0.3.29   | 10.1 MB   | #########################3            |  68%
#
# scipy-1.15.3         | 22.0 MB   | ############7                         |  34%
# libopenblas-0.3.29   | 10.1 MB   | ##########################            |  70%
#
# scipy-1.15.3         | 22.0 MB   | #############1                        |  35%
# libopenblas-0.3.29   | 10.1 MB   | ##########################7           |  72%
#
# scipy-1.15.3         | 22.0 MB   | #############5                        |  37%
# libopenblas-0.3.29   | 10.1 MB   | ###########################4          |  74%
#
# scipy-1.15.3         | 22.0 MB   | #############8                        |  38%
# libopenblas-0.3.29   | 10.1 MB   | ############################1         |  76%
#
# scipy-1.15.3         | 22.0 MB   | ##############2                       |  39%
# libopenblas-0.3.29   | 10.1 MB   | ############################8         |  78%
#
# scipy-1.15.3         | 22.0 MB   | ##############6                       |  40%
# libopenblas-0.3.29   | 10.1 MB   | #############################5        |  80%
#
# scipy-1.15.3         | 22.0 MB   | ##############9                       |  41%
# libopenblas-0.3.29   | 10.1 MB   | ##############################2       |  82%
#
# scipy-1.15.3         | 22.0 MB   | ###############3                      |  42%
# libopenblas-0.3.29   | 10.1 MB   | ##############################9       |  84%
#
# scipy-1.15.3         | 22.0 MB   | ###############7                      |  43%
# libopenblas-0.3.29   | 10.1 MB   | ###############################6      |  85%
#
# scipy-1.15.3         | 22.0 MB   | ################1                     |  44%
# libopenblas-0.3.29   | 10.1 MB   | ################################4     |  88%
#
# scipy-1.15.3         | 22.0 MB   | ################4                     |  44%
# libopenblas-0.3.29   | 10.1 MB   | #################################2    |  90%
#
# scipy-1.15.3         | 22.0 MB   | ################8                     |  45%
# libopenblas-0.3.29   | 10.1 MB   | ##################################    |  92%
#
# scipy-1.15.3         | 22.0 MB   | #################1                    |  46%
# libopenblas-0.3.29   | 10.1 MB   | ##################################7   |  94%
#
# scipy-1.15.3         | 22.0 MB   | #################4                    |  47%
# libopenblas-0.3.29   | 10.1 MB   | ###################################5  |  96%
#
# scipy-1.15.3         | 22.0 MB   | #################8                    |  48%
# libopenblas-0.3.29   | 10.1 MB   | ####################################3 |  98%
#
# scikit-learn-1.6.1   | 9.8 MB    | ####################################8 | 100%
#
# scipy-1.15.3         | 22.0 MB   | ##################1                   |  49%
# libopenblas-0.3.29   | 10.1 MB   | ##################################### | 100%
# scipy-1.15.3         | 22.0 MB   | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y xgboost
# Out:
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install -y matplotlib
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/hiraokatatsuru/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.3.1            |  py312h48ca7d4_0         264 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     fonttools-4.55.3           |  py312h80987f9_0         2.9 MB
#     freetype-2.13.3            |       h47d26ad_0         626 KB
#     jpeg-9e                    |       h80987f9_3         245 KB
#     kiwisolver-1.4.8           |  py312h313beb8_0          67 KB
#     lcms2-2.16                 |       he93ba84_0         238 KB
#     lerc-4.0.0                 |       h313beb8_0         196 KB
#     libdeflate-1.22            |       h80987f9_0          57 KB
#     libpng-1.6.39              |       h80987f9_0         283 KB
#     libtiff-4.5.1              |       hc9ead59_1         494 KB
#     libwebp-base-1.3.2         |       h80987f9_1         303 KB
#     matplotlib-3.10.0          |  py312hca03da5_0           8 KB
#     matplotlib-base-3.10.0     |  py312h7ef442a_0         8.1 MB
#     openjpeg-2.5.2             |       h54b8e55_0         324 KB
#     pillow-11.1.0              |  py312h84e58ab_0         896 KB
#     pyparsing-3.2.0            |  py312hca03da5_0         473 KB
#     unicodedata2-15.1.0        |  py312h80987f9_1         532 KB
#     ------------------------------------------------------------
#                                            Total:        15.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   contourpy          pkgs/main/osx-arm64::contourpy-1.3.1-py312h48ca7d4_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/osx-arm64::fonttools-4.55.3-py312h80987f9_0
#   freetype           pkgs/main/osx-arm64::freetype-2.13.3-h47d26ad_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9e-h80987f9_3
#   kiwisolver         pkgs/main/osx-arm64::kiwisolver-1.4.8-py312h313beb8_0
#   lcms2              pkgs/main/osx-arm64::lcms2-2.16-he93ba84_0
#   lerc               pkgs/main/osx-arm64::lerc-4.0.0-h313beb8_0
#   libdeflate         pkgs/main/osx-arm64::libdeflate-1.22-h80987f9_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.5.1-hc9ead59_1
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.3.2-h80987f9_1
#   matplotlib         pkgs/main/osx-arm64::matplotlib-3.10.0-py312hca03da5_0
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.10.0-py312h7ef442a_0
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.5.2-h54b8e55_0
#   pillow             pkgs/main/osx-arm64::pillow-11.1.0-py312h84e58ab_0
#   pyparsing          pkgs/main/osx-arm64::pyparsing-3.2.0-py312hca03da5_0
#   unicodedata2       pkgs/main/osx-arm64::unicodedata2-15.1.0-py312h80987f9_1
#
#
#
# Downloading and Extracting Packages:
# matplotlib-base-3.10 | 8.1 MB    |                                       |   0%
# fonttools-4.55.3     | 2.9 MB    |                                       |   0%
#
# pillow-11.1.0        | 896 KB    |                                       |   0%
#
#
# freetype-2.13.3      | 626 KB    |                                       |   0%
#
#
#
# unicodedata2-15.1.0  | 532 KB    |                                       |   0%
#
#
#
#
# libtiff-4.5.1        | 494 KB    |                                       |   0%
#
#
#
#
#
# pyparsing-3.2.0      | 473 KB    |                                       |   0%
#
#
#
#
#
#
# openjpeg-2.5.2       | 324 KB    |                                       |   0%
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 264 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 245 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 196 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.8     | 67 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 57 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 8 KB      |                                       |   0%
#
#
# freetype-2.13.3      | 626 KB    | #####6                                |  15%
# fonttools-4.55.3     | 2.9 MB    | 2                                     |   1%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | #1                                    |   3%
#
# matplotlib-base-3.10 | 8.1 MB    |                                       |   0%
# fonttools-4.55.3     | 2.9 MB    | #6                                    |   4%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | ########8                             |  24%
#
# pillow-11.1.0        | 896 KB    | #####2                                |  14%
#
#
# freetype-2.13.3      | 626 KB    | ###########3                          |  31%
# fonttools-4.55.3     | 2.9 MB    | ###                                   |   8%
#
# matplotlib-base-3.10 | 8.1 MB    | 2                                     |   1%
#
#
# freetype-2.13.3      | 626 KB    | ###################8                  |  54%
# fonttools-4.55.3     | 2.9 MB    | ####4                                 |  12%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | ################6                     |  45%
#
# matplotlib-base-3.10 | 8.1 MB    | 5                                     |   1%
# fonttools-4.55.3     | 2.9 MB    | #####4                                |  15%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | #####################1                |  57%
#
# matplotlib-base-3.10 | 8.1 MB    | 9                                     |   3%
#
#
# freetype-2.13.3      | 626 KB    | ##########################4           |  72%
# fonttools-4.55.3     | 2.9 MB    | ###########8                          |  32%
#
# pillow-11.1.0        | 896 KB    | ###########################           |  73%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | ##############################        |  81%
#
#
# freetype-2.13.3      | 626 KB    | ##################################### | 100%
#
#
# matplotlib-base-3.10 | 8.1 MB    | #9                                    |   5%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 896 KB    | ##################################### | 100%
#
#
#
# unicodedata2-15.1.0  | 532 KB    | ##################################### | 100%
#
#
# freetype-2.13.3      | 626 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 896 KB    | ##################################### | 100%
#
# matplotlib-base-3.10 | 8.1 MB    | ###7                                  |  10%
#
#
#
#
# libtiff-4.5.1        | 494 KB    | #1                                    |   3%
#
#
#
#
#
#
# openjpeg-2.5.2       | 324 KB    | #8                                    |   5%
#
#
#
#
# libtiff-4.5.1        | 494 KB    | ##3                                   |   6%
# fonttools-4.55.3     | 2.9 MB    | ##############6                       |  40%
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ####5                                 |  12%
# fonttools-4.55.3     | 2.9 MB    | #################8                    |  48%
#
#
#
#
#
# pyparsing-3.2.0      | 473 KB    | ###########2                          |  30%
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ######5                               |  18%
#
#
#
#
# libtiff-4.5.1        | 494 KB    | #################9                    |  49%
# fonttools-4.55.3     | 2.9 MB    | ####################5                 |  55%
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | #######5                              |  21%
#
#
#
#
# libtiff-4.5.1        | 494 KB    | ##################################7   |  94%
#
#
#
#
#
# pyparsing-3.2.0      | 473 KB    | ##############################        |  81%
# matplotlib-base-3.10 | 8.1 MB    | ########7                             |  24%
#
#
#
#
# libtiff-4.5.1        | 494 KB    | ##################################### | 100%
#
#
#
#
#
# pyparsing-3.2.0      | 473 KB    | ##################################### | 100%
#
#
#
#
# libtiff-4.5.1        | 494 KB    | ##################################### | 100%
#
#
#
#
#
# pyparsing-3.2.0      | 473 KB    | ##################################### | 100%
#
#
#
#
#
#
# openjpeg-2.5.2       | 324 KB    | ###############################       |  84%
# fonttools-4.55.3     | 2.9 MB    | ###########################5          |  74%
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | #########7                            |  26%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##                                    |   6%
#
#
#
#
#
#
# openjpeg-2.5.2       | 324 KB    | ##################################7   |  94%
# fonttools-4.55.3     | 2.9 MB    | ##############################5       |  83%
#
#
#
#
#
#
# openjpeg-2.5.2       | 324 KB    | ##################################### | 100%
#
#
#
#
#
#
# openjpeg-2.5.2       | 324 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ##########6                           |  29%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ################7                     |  45%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 264 KB    | ##2                                   |   6%
# fonttools-4.55.3     | 2.9 MB    | #################################3    |  90%
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | #############################3        |  79%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ###########################1          |  73%
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ###########5                          |  31%
# fonttools-4.55.3     | 2.9 MB    | ####################################1 |  98%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | ##################################### | 100%
# fonttools-4.55.3     | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 245 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ############6                         |  34%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 264 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 264 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 196 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.8     | 67 KB     | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.8     | 67 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 245 KB    | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 196 KB    | ##################################### | 100%
# fonttools-4.55.3     | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 57 KB     | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 245 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 245 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 245 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
conda install -c anaconda statsmodels
# Out:
# Retrieving notices: done
# Channels:
#  - anaconda
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/hiraokatatsuru/miniconda3/envs/shift_builder
#
#   added / updated specs:
#     - statsmodels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          10 KB  anaconda
#     coin-or-cgl-0.60.5         |       hc6a10a9_0         506 KB  anaconda
#     coin-or-clp-1.17.7         |       he5de485_0         1.0 MB  anaconda
#     coin-or-osi-0.108.7        |       hc6a10a9_0         390 KB  anaconda
#     coin-or-utils-2.11.6       |       he5de485_0         628 KB  anaconda
#     libgfortran-5.0.0          |11_3_0_hca03da5_28         148 KB  anaconda
#     libgfortran5-11.3.0        |      h009349e_28         1.3 MB  anaconda
#     libopenblas-0.3.29         |       hea593b9_0        13.5 MB  anaconda
#     numpy-2.2.5                |  py312h901140f_0          13 KB  anaconda
#     numpy-base-2.2.5           |  py312hae06d03_0         7.0 MB  anaconda
#     patsy-1.0.1                |  py312hca03da5_0         443 KB  anaconda
#     scipy-1.15.3               |  py312hb81b3df_0        24.3 MB  anaconda
#     setuptools-72.1.0          |  py312hca03da5_0         3.1 MB  anaconda
#     statsmodels-0.14.4         |  py312h80987f9_0        12.6 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:        64.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               anaconda/osx-arm64::blas-1.0-openblas
#   numpy-base         anaconda/osx-arm64::numpy-base-2.2.5-py312hae06d03_0
#   patsy              anaconda/osx-arm64::patsy-1.0.1-py312hca03da5_0
#   scipy              anaconda/osx-arm64::scipy-1.15.3-py312hb81b3df_0
#   statsmodels        anaconda/osx-arm64::statsmodels-0.14.4-py312h80987f9_0
#
# The following packages will be REMOVED:
#
#   libblas-3.9.0-31_h10e41b3_openblas
#   libcblas-3.9.0-31_hb3479ef_openblas
#   liblapack-3.9.0-31_hc9a63f6_openblas
#   liblapacke-3.9.0-31_hbb7bcf8_openblas
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   coin-or-cgl        conda-forge::coin-or-cgl-0.60.7-hf050~ --> anaconda::coin-or-cgl-0.60.5-hc6a10a9_0
#   coin-or-clp        conda-forge::coin-or-clp-1.17.8-h65c2~ --> anaconda::coin-or-clp-1.17.7-he5de485_0
#   coin-or-osi        conda-forge::coin-or-osi-0.108.10-h0d~ --> anaconda::coin-or-osi-0.108.7-hc6a10a9_0
#   coin-or-utils      conda-forge::coin-or-utils-2.11.11-h0~ --> anaconda::coin-or-utils-2.11.6-he5de485_0
#   libgfortran        conda-forge::libgfortran-14.2.0-heb5d~ --> anaconda::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       conda-forge::libgfortran5-14.2.0-h2c4~ --> anaconda::libgfortran5-11.3.0-h009349e_28
#   libopenblas        conda-forge::libopenblas-0.3.29-openm~ --> anaconda::libopenblas-0.3.29-hea593b9_0
#   numpy              conda-forge::numpy-2.2.5-py312h7c1f31~ --> anaconda::numpy-2.2.5-py312h901140f_0
#   setuptools         pkgs/main::setuptools-75.8.0-py312hca~ --> anaconda::setuptools-72.1.0-py312hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# scipy-1.15.3         | 24.3 MB   |                                       |   0%
# libopenblas-0.3.29   | 13.5 MB   |                                       |   0%
#
# statsmodels-0.14.4   | 12.6 MB   |                                       |   0%
#
#
# numpy-base-2.2.5     | 7.0 MB    |                                       |   0%
#
#
#
# setuptools-72.1.0    | 3.1 MB    |                                       |   0%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    |                                       |   0%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    |                                       |   0%
#
#
#
#
#
#
#
# coin-or-cgl-0.60.5   | 506 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# patsy-1.0.1          | 443 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# coin-or-osi-0.108.7  | 390 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 148 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | 9                                     |   3%
# scipy-1.15.3         | 24.3 MB   | #5                                    |   4%
# libopenblas-0.3.29   | 13.5 MB   | 6                                     |   2%
# scipy-1.15.3         | 24.3 MB   | ##1                                   |   6%
# scipy-1.15.3         | 24.3 MB   | ##6                                   |   7%
# libopenblas-0.3.29   | 13.5 MB   | ###6                                  |  10%
# scipy-1.15.3         | 24.3 MB   | ###4                                  |   9%
# scipy-1.15.3         | 24.3 MB   | ###9                                  |  11%
# scipy-1.15.3         | 24.3 MB   | ####4                                 |  12%
# scipy-1.15.3         | 24.3 MB   | ####8                                 |  13%
# libopenblas-0.3.29   | 13.5 MB   | #######7                              |  21%
#
#
# scipy-1.15.3         | 24.3 MB   | #####3                                |  14%
# libopenblas-0.3.29   | 13.5 MB   | ########5                             |  23%
#
#
#
# scipy-1.15.3         | 24.3 MB   | #####7                                |  16%
#
#
# numpy-base-2.2.5     | 7.0 MB    | 4                                     |   1%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | 7                                     |   2%
#
#
# numpy-base-2.2.5     | 7.0 MB    | 9                                     |   3%
#
# scipy-1.15.3         | 24.3 MB   | ######1                               |  17%
# libopenblas-0.3.29   | 13.5 MB   | #########1                            |  25%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #6                                    |   4%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | #8                                    |   5%
#
# statsmodels-0.14.4   | 12.6 MB   | 2                                     |   1%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ##4                                   |   7%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ###                                   |   8%
#
# scipy-1.15.3         | 24.3 MB   | ######5                               |  18%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###6                                  |  10%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ####1                                 |  11%
#
# statsmodels-0.14.4   | 12.6 MB   | 6                                     |   2%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ####7                                 |  13%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | #####                                 |  14%
#
# statsmodels-0.14.4   | 12.6 MB   | 8                                     |   2%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | #######7                              |  21%
# libopenblas-0.3.29   | 13.5 MB   | #########6                            |  26%
#
#
# scipy-1.15.3         | 24.3 MB   | ######8                               |  18%
#
# statsmodels-0.14.4   | 12.6 MB   | #                                     |   3%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | #########                             |  24%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #########5                            |  26%
#
# statsmodels-0.14.4   | 12.6 MB   | #4                                    |   4%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ##############6                       |  40%
# scipy-1.15.3         | 24.3 MB   | #######                               |  19%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | #################1                    |  46%
#
# statsmodels-0.14.4   | 12.6 MB   | ##                                    |   5%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###########                           |  30%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ######################2               |  60%
#
# statsmodels-0.14.4   | 12.6 MB   | ##2                                   |   6%
#
#
# scipy-1.15.3         | 24.3 MB   | #######2                              |  20%
#
# statsmodels-0.14.4   | 12.6 MB   | ###                                   |   8%
# libopenblas-0.3.29   | 13.5 MB   | ##########3                           |  28%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | #########################2            |  68%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #############9                        |  38%
#
# statsmodels-0.14.4   | 12.6 MB   | ###3                                  |   9%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ##############################8       |  83%
#
# scipy-1.15.3         | 24.3 MB   | #######4                              |  20%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###############                       |  41%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ##################################2   |  93%
#
# statsmodels-0.14.4   | 12.6 MB   | ###9                                  |  11%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | ##########6                           |  29%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ################                      |  43%
#
# scipy-1.15.3         | 24.3 MB   | #######5                              |  20%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    | 4                                     |   1%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #################2                    |  47%
#
# statsmodels-0.14.4   | 12.6 MB   | ####8                                 |  13%
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | #######6                              |  21%
#
# statsmodels-0.14.4   | 12.6 MB   | #####2                                |  14%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ##################2                   |  49%
# libopenblas-0.3.29   | 13.5 MB   | ##########8                           |  29%
#
#
#
# setuptools-72.1.0    | 3.1 MB    | ##################################### | 100%
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | #######7                              |  21%
#
# statsmodels-0.14.4   | 12.6 MB   | #####5                                |  15%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    | #############5                        |  37%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###################1                  |  52%
#
# statsmodels-0.14.4   | 12.6 MB   | #####9                                |  16%
# scipy-1.15.3         | 24.3 MB   | #######8                              |  21%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    | #################4                    |  47%
#
# statsmodels-0.14.4   | 12.6 MB   | ######3                               |  17%
# libopenblas-0.3.29   | 13.5 MB   | ###########1                          |  30%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###################9                  |  54%
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | #######9                              |  22%
#
# statsmodels-0.14.4   | 12.6 MB   | ######7                               |  18%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ####################7                 |  56%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    | ##########################2           |  71%
# scipy-1.15.3         | 24.3 MB   | ########                              |  22%
#
# statsmodels-0.14.4   | 12.6 MB   | #######1                              |  19%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #####################5                |  58%
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ########1                             |  22%
# libopenblas-0.3.29   | 13.5 MB   | ###########4                          |  31%
#
# statsmodels-0.14.4   | 12.6 MB   | #######5                              |  20%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ######################2               |  60%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    | ##################################9   |  94%
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ########2                             |  22%
# libopenblas-0.3.29   | 13.5 MB   | ###########5                          |  31%
#
# statsmodels-0.14.4   | 12.6 MB   | ########1                             |  22%
#
#
# scipy-1.15.3         | 24.3 MB   | ########3                             |  23%
#
#
#
#
# libgfortran5-11.3.0  | 1.3 MB    | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | ###########6                          |  32%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ########################2             |  66%
#
# scipy-1.15.3         | 24.3 MB   | ########4                             |  23%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #########################3            |  69%
# libopenblas-0.3.29   | 13.5 MB   | ###########8                          |  32%
#
# scipy-1.15.3         | 24.3 MB   | ########6                             |  23%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ##########################4           |  72%
#
# statsmodels-0.14.4   | 12.6 MB   | #########4                            |  25%
# scipy-1.15.3         | 24.3 MB   | ########7                             |  24%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###########################4          |  74%
#
# statsmodels-0.14.4   | 12.6 MB   | #########9                            |  27%
# libopenblas-0.3.29   | 13.5 MB   | ############1                         |  33%
#
#
# scipy-1.15.3         | 24.3 MB   | ########8                             |  24%
#
# statsmodels-0.14.4   | 12.6 MB   | ##########5                           |  29%
# libopenblas-0.3.29   | 13.5 MB   | ############2                         |  33%
#
#
# scipy-1.15.3         | 24.3 MB   | ########9                             |  24%
#
# statsmodels-0.14.4   | 12.6 MB   | ###########                           |  30%
# libopenblas-0.3.29   | 13.5 MB   | ############3                         |  33%
#
#
# scipy-1.15.3         | 24.3 MB   | #########1                            |  25%
#
# statsmodels-0.14.4   | 12.6 MB   | ###########6                          |  31%
# libopenblas-0.3.29   | 13.5 MB   | ############5                         |  34%
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | #########2                            |  25%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ################################5     |  88%
#
# statsmodels-0.14.4   | 12.6 MB   | ############1                         |  33%
# libopenblas-0.3.29   | 13.5 MB   | ############6                         |  34%
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | #########4                            |  25%
#
# statsmodels-0.14.4   | 12.6 MB   | ############6                         |  34%
#
#
# numpy-base-2.2.5     | 7.0 MB    | #################################5    |  91%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | #####5                                |  15%
# scipy-1.15.3         | 24.3 MB   | #########5                            |  26%
#
# statsmodels-0.14.4   | 12.6 MB   | #############1                        |  36%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ##################################6   |  94%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ########8                             |  24%
# scipy-1.15.3         | 24.3 MB   | #########7                            |  26%
#
# statsmodels-0.14.4   | 12.6 MB   | #############6                        |  37%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ###################################6  |  96%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ##############3                       |  39%
# scipy-1.15.3         | 24.3 MB   | #########8                            |  27%
#
# statsmodels-0.14.4   | 12.6 MB   | ##############1                       |  38%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ##################2                   |  49%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ####################################6 |  99%
# scipy-1.15.3         | 24.3 MB   | ##########                            |  27%
#
# statsmodels-0.14.4   | 12.6 MB   | ##############6                       |  40%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ##################################### | 100%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ######################7               |  61%
# scipy-1.15.3         | 24.3 MB   | ##########2                           |  28%
#
# statsmodels-0.14.4   | 12.6 MB   | ###############1                      |  41%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | #############################9        |  81%
# libopenblas-0.3.29   | 13.5 MB   | #############7                        |  37%
#
# scipy-1.15.3         | 24.3 MB   | ##########4                           |  28%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ####################################5 |  99%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | #############9                        |  38%
#
# scipy-1.15.3         | 24.3 MB   | ##########6                           |  29%
#
#
#
#
#
# coin-or-clp-1.17.7   | 1.0 MB    | ##################################### | 100%
#
# scipy-1.15.3         | 24.3 MB   | ##########8                           |  29%
# libopenblas-0.3.29   | 13.5 MB   | ##############2                       |  38%
#
# scipy-1.15.3         | 24.3 MB   | ###########1                          |  30%
# libopenblas-0.3.29   | 13.5 MB   | ##############5                       |  39%
#
#
# numpy-base-2.2.5     | 7.0 MB    | ##################################### | 100%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | 9                                     |   3%
# libopenblas-0.3.29   | 13.5 MB   | ##############7                       |  40%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ###7                                  |  10%
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###########2                          |  31%
#
# statsmodels-0.14.4   | 12.6 MB   | ##################3                   |  50%
#
#
#
#
#
#
#
# coin-or-cgl-0.60.5   | 506 KB    | #1                                    |   3%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ########4                             |  23%
# scipy-1.15.3         | 24.3 MB   | ###########4                          |  31%
#
#
#
#
#
#
#
# coin-or-cgl-0.60.5   | 506 KB    | #######                               |  19%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ##############1                       |  38%
# libopenblas-0.3.29   | 13.5 MB   | ###############                       |  41%
#
# statsmodels-0.14.4   | 12.6 MB   | ##################7                   |  51%
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###########5                          |  31%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ##################8                   |  51%
#
#
#
#
#
#
#
# coin-or-cgl-0.60.5   | 506 KB    | #################5                    |  47%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | #####################6                |  59%
# libopenblas-0.3.29   | 13.5 MB   | ###############2                      |  41%
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###########7                          |  32%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ########################5             |  66%
#
# statsmodels-0.14.4   | 12.6 MB   | ###################1                  |  52%
# scipy-1.15.3         | 24.3 MB   | ###########7                          |  32%
#
#
#
#
#
#
#
# coin-or-cgl-0.60.5   | 506 KB    | ##########################8           |  73%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | #############################2        |  79%
# libopenblas-0.3.29   | 13.5 MB   | ###############5                      |  42%
#
# statsmodels-0.14.4   | 12.6 MB   | ###################4                  |  52%
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###########9                          |  32%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | #################################9    |  92%
#
#
#
#
#
#
#
# coin-or-cgl-0.60.5   | 506 KB    | ##################################### | 100%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | ###############7                      |  43%
#
# statsmodels-0.14.4   | 12.6 MB   | ###################7                  |  53%
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ############1                         |  33%
#
#
#
#
#
#
# coin-or-utils-2.11.6 | 628 KB    | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | ################1                     |  44%
#
# scipy-1.15.3         | 24.3 MB   | ############3                         |  33%
# libopenblas-0.3.29   | 13.5 MB   | ################4                     |  44%
#
# scipy-1.15.3         | 24.3 MB   | ############5                         |  34%
# libopenblas-0.3.29   | 13.5 MB   | ################7                     |  45%
#
# scipy-1.15.3         | 24.3 MB   | ############7                         |  34%
# libopenblas-0.3.29   | 13.5 MB   | #################                     |  46%
#
# scipy-1.15.3         | 24.3 MB   | ############8                         |  35%
# scipy-1.15.3         | 24.3 MB   | #############                         |  35%
#
# statsmodels-0.14.4   | 12.6 MB   | #####################4                |  58%
# scipy-1.15.3         | 24.3 MB   | #############2                        |  36%
#
# statsmodels-0.14.4   | 12.6 MB   | #####################7                |  59%
# scipy-1.15.3         | 24.3 MB   | #############4                        |  36%
#
# statsmodels-0.14.4   | 12.6 MB   | ######################1               |  60%
# scipy-1.15.3         | 24.3 MB   | #############6                        |  37%
#
# statsmodels-0.14.4   | 12.6 MB   | ######################5               |  61%
# scipy-1.15.3         | 24.3 MB   | #############9                        |  38%
#
# statsmodels-0.14.4   | 12.6 MB   | #######################               |  62%
#
#
#
#
#
#
#
#
# patsy-1.0.1          | 443 KB    | #3                                    |   4%
# scipy-1.15.3         | 24.3 MB   | ##############1                       |  38%
#
# statsmodels-0.14.4   | 12.6 MB   | #######################5              |  64%
# libopenblas-0.3.29   | 13.5 MB   | ###################5                  |  53%
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ##############4                       |  39%
#
# statsmodels-0.14.4   | 12.6 MB   | #######################9              |  65%
# libopenblas-0.3.29   | 13.5 MB   | ####################                  |  54%
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ##############6                       |  40%
#
# statsmodels-0.14.4   | 12.6 MB   | ########################4             |  66%
# libopenblas-0.3.29   | 13.5 MB   | ####################5                 |  55%
#
#
#
#
#
#
#
#
# patsy-1.0.1          | 443 KB    | #####################3                |  58%
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ##############9                       |  40%
#
# statsmodels-0.14.4   | 12.6 MB   | ########################9             |  67%
# libopenblas-0.3.29   | 13.5 MB   | ####################9                 |  57%
#
#
#
#
#
#
#
#
# patsy-1.0.1          | 443 KB    | ################################      |  87%
#
#
#
#
#
#
#
#
#
# coin-or-osi-0.108.7  | 390 KB    | #######5                              |  21%
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###############1                      |  41%
# libopenblas-0.3.29   | 13.5 MB   | #####################3                |  58%
#
#
#
#
#
#
#
#
#
# coin-or-osi-0.108.7  | 390 KB    | ###############1                      |  41%
#
#
#
#
#
#
#
#
# patsy-1.0.1          | 443 KB    | ##################################### | 100%
#
# statsmodels-0.14.4   | 12.6 MB   | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 148 KB    | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 148 KB    | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 148 KB    | ####################                  |  54%
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###############3                      |  42%
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 148 KB    | ####################################  |  97%
#
# statsmodels-0.14.4   | 12.6 MB   | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 148 KB    | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | #####################8                |  59%
#
#
#
#
#
#
#
#
#
# coin-or-osi-0.108.7  | 390 KB    | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###############5                      |  42%
#
# statsmodels-0.14.4   | 12.6 MB   | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# coin-or-osi-0.108.7  | 390 KB    | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 13 KB     | ##################################### | 100%
# libopenblas-0.3.29   | 13.5 MB   | ######################1               |  60%
#
#
#
#
#
#
#
#
#
# coin-or-osi-0.108.7  | 390 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 24.3 MB   | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
#
# statsmodels-0.14.4   | 12.6 MB   | ##########################4           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
# scipy-1.15.3         | 24.3 MB   | ################                      |  43%
#
# statsmodels-0.14.4   | 12.6 MB   | ##########################9           |  73%
# scipy-1.15.3         | 24.3 MB   | ################3                     |  44%
#
# statsmodels-0.14.4   | 12.6 MB   | ###########################5          |  74%
# scipy-1.15.3         | 24.3 MB   | ################6                     |  45%
#
# statsmodels-0.14.4   | 12.6 MB   | ############################          |  76%
# scipy-1.15.3         | 24.3 MB   | ################8                     |  46%
#
# statsmodels-0.14.4   | 12.6 MB   | ############################5         |  77%
# scipy-1.15.3         | 24.3 MB   | #################1                    |  46%
#
# statsmodels-0.14.4   | 12.6 MB   | #############################         |  79%
# scipy-1.15.3         | 24.3 MB   | #################4                    |  47%
#
# statsmodels-0.14.4   | 12.6 MB   | #############################5        |  80%
# libopenblas-0.3.29   | 13.5 MB   | #########################7            |  70%
#
# scipy-1.15.3         | 24.3 MB   | #################7                    |  48%
# libopenblas-0.3.29   | 13.5 MB   | ##########################2           |  71%
#
# scipy-1.15.3         | 24.3 MB   | ##################1                   |  49%
# libopenblas-0.3.29   | 13.5 MB   | ##########################8           |  72%
#
# scipy-1.15.3         | 24.3 MB   | ##################4                   |  50%
# libopenblas-0.3.29   | 13.5 MB   | ###########################3          |  74%
#
# scipy-1.15.3         | 24.3 MB   | ##################6                   |  51%
# libopenblas-0.3.29   | 13.5 MB   | ###########################9          |  75%
#
# scipy-1.15.3         | 24.3 MB   | ###################                   |  51%
# libopenblas-0.3.29   | 13.5 MB   | ############################6         |  77%
#
# scipy-1.15.3         | 24.3 MB   | ###################3                  |  52%
# libopenblas-0.3.29   | 13.5 MB   | #############################2        |  79%
#
# scipy-1.15.3         | 24.3 MB   | ###################6                  |  53%
# libopenblas-0.3.29   | 13.5 MB   | #############################7        |  80%
#
# scipy-1.15.3         | 24.3 MB   | ###################9                  |  54%
# libopenblas-0.3.29   | 13.5 MB   | ##############################2       |  82%
#
# scipy-1.15.3         | 24.3 MB   | ####################3                 |  55%
# libopenblas-0.3.29   | 13.5 MB   | ##############################6       |  83%
#
# scipy-1.15.3         | 24.3 MB   | ####################5                 |  56%
# libopenblas-0.3.29   | 13.5 MB   | ##############################9       |  84%
#
# scipy-1.15.3         | 24.3 MB   | ####################6                 |  56%
# libopenblas-0.3.29   | 13.5 MB   | ###############################1      |  84%
#
# scipy-1.15.3         | 24.3 MB   | ####################8                 |  56%
#
# statsmodels-0.14.4   | 12.6 MB   | ####################################  |  97%
# scipy-1.15.3         | 24.3 MB   | #####################                 |  57%
#
# statsmodels-0.14.4   | 12.6 MB   | ####################################3 |  98%
# scipy-1.15.3         | 24.3 MB   | #####################1                |  57%
#
# scipy-1.15.3         | 24.3 MB   | #####################3                |  58%
# scipy-1.15.3         | 24.3 MB   | #####################4                |  58%
#
# statsmodels-0.14.4   | 12.6 MB   | ####################################8 | 100%
# scipy-1.15.3         | 24.3 MB   | #####################5                |  58%
#
# statsmodels-0.14.4   | 12.6 MB   | ##################################### | 100%
#
# statsmodels-0.14.4   | 12.6 MB   | ##################################### | 100%
# scipy-1.15.3         | 24.3 MB   | #####################6                |  59%
# scipy-1.15.3         | 24.3 MB   | #####################9                |  59%
# scipy-1.15.3         | 24.3 MB   | ######################1               |  60%
# scipy-1.15.3         | 24.3 MB   | ######################4               |  61%
# scipy-1.15.3         | 24.3 MB   | ######################8               |  62%
# scipy-1.15.3         | 24.3 MB   | #######################2              |  63%
# scipy-1.15.3         | 24.3 MB   | #######################5              |  64%
# scipy-1.15.3         | 24.3 MB   | #######################8              |  64%
# scipy-1.15.3         | 24.3 MB   | ########################              |  65%
# libopenblas-0.3.29   | 13.5 MB   | ###################################6  |  96%
#
# scipy-1.15.3         | 24.3 MB   | ########################5             |  66%
# scipy-1.15.3         | 24.3 MB   | ########################9             |  67%
# libopenblas-0.3.29   | 13.5 MB   | ####################################8 |  99%
# scipy-1.15.3         | 24.3 MB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge optuna
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.0
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/hiraokatatsuru/miniconda3/envs/shift_builder
#
#   added / updated specs:
#     - optuna
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alembic-1.16.1             |     pyhd8ed1ab_0         161 KB  conda-forge
#     colorama-0.4.6             |     pyhd8ed1ab_1          26 KB  conda-forge
#     colorlog-6.9.0             |     pyh707e725_1          15 KB  conda-forge
#     greenlet-3.2.3             |  py312hd8f9ff3_0         226 KB  conda-forge
#     mako-1.3.10                |     pyhd8ed1ab_0          66 KB  conda-forge
#     optuna-4.3.0               |     pyhd8ed1ab_0         232 KB  conda-forge
#     sqlalchemy-2.0.41          |  py312hea69d52_0         3.3 MB  conda-forge
#     tqdm-4.67.1                |     pyhd8ed1ab_1          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   alembic            conda-forge/noarch::alembic-1.16.1-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_1
#   colorlog           conda-forge/noarch::colorlog-6.9.0-pyh707e725_1
#   greenlet           conda-forge/osx-arm64::greenlet-3.2.3-py312hd8f9ff3_0
#   mako               conda-forge/noarch::mako-1.3.10-pyhd8ed1ab_0
#   optuna             conda-forge/noarch::optuna-4.3.0-pyhd8ed1ab_0
#   sqlalchemy         conda-forge/osx-arm64::sqlalchemy-2.0.41-py312hea69d52_0
#   tqdm               conda-forge/noarch::tqdm-4.67.1-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# sqlalchemy-2.0.41    | 3.3 MB    |                                       |   0%
# optuna-4.3.0         | 232 KB    |                                       |   0%
#
# greenlet-3.2.3       | 226 KB    |                                       |   0%
#
#
# alembic-1.16.1       | 161 KB    |                                       |   0%
#
#
#
# tqdm-4.67.1          | 87 KB     |                                       |   0%
#
#
#
#
# mako-1.3.10          | 66 KB     |                                       |   0%
#
#
#
#
#
# colorama-0.4.6       | 26 KB     |                                       |   0%
#
#
#
#
#
#
# colorlog-6.9.0       | 15 KB     |                                       |   0%
#
#
# alembic-1.16.1       | 161 KB    | ###6                                  |  10%
#
# sqlalchemy-2.0.41    | 3.3 MB    | 1                                     |   0%
#
#
#
# tqdm-4.67.1          | 87 KB     | ######7                               |  18%
#
#
#
# tqdm-4.67.1          | 87 KB     | ##################################### | 100%
# optuna-4.3.0         | 232 KB    | ##5                                   |   7%
#
# greenlet-3.2.3       | 226 KB    | ####################9                 |  57%
#
#
#
# tqdm-4.67.1          | 87 KB     | ##################################### | 100%
#
# sqlalchemy-2.0.41    | 3.3 MB    | #3                                    |   4%
#
# greenlet-3.2.3       | 226 KB    | ##################################### | 100%
#
#
# alembic-1.16.1       | 161 KB    | #############################4        |  80%
#
#
# alembic-1.16.1       | 161 KB    | ##################################### | 100%
#
#
#
#
# mako-1.3.10          | 66 KB     | ########9                             |  24%
#
#
# alembic-1.16.1       | 161 KB    | ##################################### | 100%
#
#
#
#
# mako-1.3.10          | 66 KB     | ##################################### | 100%
#
#
#
#
# sqlalchemy-2.0.41    | 3.3 MB    | #####9                                |  16%
# optuna-4.3.0         | 232 KB    | ##########2                           |  28%
#
#
#
#
#
# colorama-0.4.6       | 26 KB     | ######################4               |  61%
#
#
#
#
#
# colorama-0.4.6       | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
# colorlog-6.9.0       | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
# colorlog-6.9.0       | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
# colorlog-6.9.0       | 15 KB     | ##################################### | 100%
#
#
#
#
#
# sqlalchemy-2.0.41    | 3.3 MB    | ########7                             |  24%
# optuna-4.3.0         | 232 KB    | ###############3                      |  41%
# sqlalchemy-2.0.41    | 3.3 MB    | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
